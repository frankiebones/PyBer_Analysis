# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# 4               46  Urban
# ...            ...    ...
# 2370             6  Rural
# 2371             2  Rural
# 2372             1  Rural
# 2373             4  Rural
# 2374             1  Rural
#
# [2375 rows x 6 columns]

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_rides = pyber_data_df.groupby('type')['ride_id'].count()

total_rides
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
total_drivers = city_data_df.groupby('type')['driver_count'].sum()

total_drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_fares = pyber_data_df.groupby('type')['fare'].sum()

total_fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
avg_ride_fare = total_fares / total_rides

avg_ride_fare
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
avg_driver_fare = total_fares / total_drivers

avg_driver_fare
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
summary_df = pd.DataFrame({
    "Total Rides": total_rides,
    "Total Drivers": total_drivers,
    "Total Fares": total_fares,
    "Average Fare per Ride": avg_ride_fare,
    "Average Fare per Driver": avg_driver_fare
})

# %%
#  7. Cleaning up the DataFrame. Delete the index name
summary_df.index.name = None

summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
summary_df = summary_df.style.format({
    "Total Fares": "${:,.2f}",
    "Average Fare per Ride": "${:.2f}",
    "Average Fare per Driver": "${:.2f}"
})

summary_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_4d722_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Rides</th>
#       <th class="col_heading level0 col1" >Total Drivers</th>
#       <th class="col_heading level0 col2" >Total Fares</th>
#       <th class="col_heading level0 col3" >Average Fare per Ride</th>
#       <th class="col_heading level0 col4" >Average Fare per Driver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d722_level0_row0" class="row_heading level0 row0" >Rural</th>
#       <td id="T_4d722_row0_col0" class="data row0 col0" >125</td>
#       <td id="T_4d722_row0_col1" class="data row0 col1" >78</td>
#       <td id="T_4d722_row0_col2" class="data row0 col2" >$4,327.93</td>
#       <td id="T_4d722_row0_col3" class="data row0 col3" >$34.62</td>
#       <td id="T_4d722_row0_col4" class="data row0 col4" >$55.49</td>
#     </tr>
#     <tr>
#       <th id="T_4d722_level0_row1" class="row_heading level0 row1" >Suburban</th>
#       <td id="T_4d722_row1_col0" class="data row1 col0" >625</td>
#       <td id="T_4d722_row1_col1" class="data row1 col1" >490</td>
#       <td id="T_4d722_row1_col2" class="data row1 col2" >$19,356.33</td>
#       <td id="T_4d722_row1_col3" class="data row1 col3" >$30.97</td>
#       <td id="T_4d722_row1_col4" class="data row1 col4" >$39.50</td>
#     </tr>
#     <tr>
#       <th id="T_4d722_level0_row2" class="row_heading level0 row2" >Urban</th>
#       <td id="T_4d722_row2_col0" class="data row2 col0" >1625</td>
#       <td id="T_4d722_row2_col1" class="data row2 col1" >2405</td>
#       <td id="T_4d722_row2_col2" class="data row2 col2" >$39,854.38</td>
#       <td id="T_4d722_row2_col3" class="data row2 col3" >$24.53</td>
#       <td id="T_4d722_row2_col4" class="data row2 col4" >$16.57</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
fare_per_date_df = pyber_data_df.groupby(['type', 'date'])['fare'].sum()

fare_per_date_df
# Out:
# type   date
# Rural  2019-01-01 09:45:36    43.69
#        2019-01-02 11:18:32    52.12
#        2019-01-03 19:51:01    19.90
#        2019-01-04 03:31:26    24.88
#        2019-01-06 07:38:40    47.33
#                               ...
# Urban  2019-05-08 04:20:00    21.99
#        2019-05-08 04:39:49    18.45
#        2019-05-08 07:29:01    18.55
#        2019-05-08 11:38:35    19.77
#        2019-05-08 13:10:18    18.04
# Name: fare, Length: 2375, dtype: float64

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
fare_per_date_df = fare_per_date_df.reset_index()

fare_per_date_df
# Out:
#        type                 date   fare
# 0     Rural  2019-01-01 09:45:36  43.69
# 1     Rural  2019-01-02 11:18:32  52.12
# 2     Rural  2019-01-03 19:51:01  19.90
# 3     Rural  2019-01-04 03:31:26  24.88
# 4     Rural  2019-01-06 07:38:40  47.33
# ...     ...                  ...    ...
# 2370  Urban  2019-05-08 04:20:00  21.99
# 2371  Urban  2019-05-08 04:39:49  18.45
# 2372  Urban  2019-05-08 07:29:01  18.55
# 2373  Urban  2019-05-08 11:38:35  19.77
# 2374  Urban  2019-05-08 13:10:18  18.04
#
# [2375 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
fare_per_date_df = fare_per_date_df.pivot(index='date', columns='type', values='fare')

fare_per_date_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
date_range_df = fare_per_date_df.loc['2019-01-01' : '2019-04-29']

date_range_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)

date_range_df.index = pd.to_datetime(date_range_df.index)

date_range_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
# 7. Check that the datatype for the index is datetime using df.info()
date_range_df.info('date')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2196 entries, 2019-01-01 00:08:16 to 2019-04-28 19:35:03
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  573 non-null    float64
#  2   Urban     1509 non-null   float64
# dtypes: float64(3)
# memory usage: 68.6 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
weekly_bins_df = date_range_df.resample('W').sum().style.format()\
    .bar(subset=["Rural",], color='lightcoral', vmin=0, vmax=2500)\
    .bar(subset=["Suburban"], color='lightskyblue', vmin=0, vmax=2500)\
    .bar(subset=["Urban"], color='gold', vmin=0, vmax=2500)
#.highlight_max(color='lightskyblue').highlight_min(color='lightcoral')

weekly_bins_df
# Out:
# <style type="text/css">
# #T_2af1e_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 7.5%, transparent 7.5%);
# }
# #T_2af1e_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 28.9%, transparent 28.9%);
# }
# #T_2af1e_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 66.5%, transparent 66.5%);
# }
# #T_2af1e_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 2.7%, transparent 2.7%);
# }
# #T_2af1e_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 44.2%, transparent 44.2%);
# }
# #T_2af1e_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 82.0%, transparent 82.0%);
# }
# #T_2af1e_row2_col0, #T_2af1e_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 12.2%, transparent 12.2%);
# }
# #T_2af1e_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 48.7%, transparent 48.7%);
# }
# #T_2af1e_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 77.6%, transparent 77.6%);
# }
# #T_2af1e_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 7.2%, transparent 7.2%);
# }
# #T_2af1e_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 48.1%, transparent 48.1%);
# }
# #T_2af1e_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 85.2%, transparent 85.2%);
# }
# #T_2af1e_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 13.3%, transparent 13.3%);
# }
# #T_2af1e_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 41.7%, transparent 41.7%);
# }
# #T_2af1e_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 83.5%, transparent 83.5%);
# }
# #T_2af1e_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 4.6%, transparent 4.6%);
# }
# #T_2af1e_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 39.0%, transparent 39.0%);
# }
# #T_2af1e_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 86.5%, transparent 86.5%);
# }
# #T_2af1e_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 3.8%, transparent 3.8%);
# }
# #T_2af1e_row6_col1, #T_2af1e_row12_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 41.8%, transparent 41.8%);
# }
# #T_2af1e_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 89.4%, transparent 89.4%);
# }
# #T_2af1e_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 16.8%, transparent 16.8%);
# }
# #T_2af1e_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 56.5%, transparent 56.5%);
# }
# #T_2af1e_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 98.7%, transparent 98.7%);
# }
# #T_2af1e_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 7.0%, transparent 7.0%);
# }
# #T_2af1e_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 34.3%, transparent 34.3%);
# }
# #T_2af1e_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 88.7%, transparent 88.7%);
# }
# #T_2af1e_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 37.0%, transparent 37.0%);
# }
# #T_2af1e_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 98.8%, transparent 98.8%);
# }
# #T_2af1e_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 6.5%, transparent 6.5%);
# }
# #T_2af1e_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 36.2%, transparent 36.2%);
# }
# #T_2af1e_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 81.8%, transparent 81.8%);
# }
# #T_2af1e_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 7.6%, transparent 7.6%);
# }
# #T_2af1e_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 44.9%, transparent 44.9%);
# }
# #T_2af1e_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 94.7%, transparent 94.7%);
# }
# #T_2af1e_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 8.0%, transparent 8.0%);
# }
# #T_2af1e_row12_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 77.7%, transparent 77.7%);
# }
# #T_2af1e_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 20.0%, transparent 20.0%);
# }
# #T_2af1e_row13_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 40.4%, transparent 40.4%);
# }
# #T_2af1e_row13_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 94.3%, transparent 94.3%);
# }
# #T_2af1e_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 10.8%, transparent 10.8%);
# }
# #T_2af1e_row14_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 31.4%, transparent 31.4%);
# }
# #T_2af1e_row14_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 95.6%, transparent 95.6%);
# }
# #T_2af1e_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 8.6%, transparent 8.6%);
# }
# #T_2af1e_row15_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 46.0%, transparent 46.0%);
# }
# #T_2af1e_row15_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 92.2%, transparent 92.2%);
# }
# #T_2af1e_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightcoral 7.7%, transparent 7.7%);
# }
# #T_2af1e_row16_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightskyblue 54.3%, transparent 54.3%);
# }
# #T_2af1e_row16_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,gold 89.5%, transparent 89.5%);
# }
# </style>
# <table id="T_2af1e_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >type</th>
#       <th class="col_heading level0 col0" >Rural</th>
#       <th class="col_heading level0 col1" >Suburban</th>
#       <th class="col_heading level0 col2" >Urban</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2af1e_level0_row0" class="row_heading level0 row0" >2019-01-06 00:00:00</th>
#       <td id="T_2af1e_row0_col0" class="data row0 col0" >187.920000</td>
#       <td id="T_2af1e_row0_col1" class="data row0 col1" >721.600000</td>
#       <td id="T_2af1e_row0_col2" class="data row0 col2" >1661.680000</td>
#     </tr>
#     <tr>
#       <th id="T_2af1e_level0_row1" class="row_heading level0 row1" >2019-01-13 00:00:00</th>
#       <td id="T_2af1e_row1_col0" class="data row1 col0" >67.650000</td>
#       <td id="T_2af1e_row1_col1" class="data row1 col1" >1105.130000</td>
#       <td id="T_2af1e_row1_col2" class="data row1 col2" >2050.430000</td>
#     </tr>
#     <tr>
#       <th id="T_2af1e_level0_row2" class="row_heading level0 row2" >2019-01-20 00:00:00</th>
#       <td id="T_2af1e_row2_col0" class="data row2 col0" >306.000000</td>
#       <td id="T_2af1e_row2_col1" class="data row2 col1" >1218.200000</td>
#       <td id="T_2af1e_row2_col2" class="data row2 col2" >1939.020000</td>
#     </tr>
#     <tr>
#       <th id="T_2af1e_level0_row3" class="row_heading level0 row3" >2019-01-27 00:00:00</th>
#       <td id="T_2af1e_row3_col0" class="data row3 col0" >179.690000</td>
#       <td id="T_2af1e_row3_col1" class="data row3 col1" >1203.280000</td>
#       <td id="T_2af1e_row3_col2" class="data row3 col

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
